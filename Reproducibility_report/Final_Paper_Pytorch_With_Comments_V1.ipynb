# %% [markdown]
# # [Title]
# This is a single notebook to reproduce the results in the final version of the NIPS paper [Deep, complex, invertible networks for inversion of transmission effects in multimode optical fibres] using PyTorch.
#
# # PART 1 : Pytorch models building, training and testing

# %% [markdown]
# ## 1.1 General setup

# %%
# %%time 
# Change to appropriate path
my_path = ''


import os
import gc

from matplotlib import pyplot as plt
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['axes.linewidth'] = 0

import numpy as np
import pickle
import h5py
import cv2
from IPython.display import display, clear_output
from copy import copy
from matplotlib import colors

from ComplexNetsTorch import *

import subprocess
import imageio
from IPython.display import HTML

def axes_off():
    cur_axes = plt.gca()
    cur_axes.axes.get_xaxis().set_visible(False)
    cur_axes.axes.get_yaxis().set_visible(False)
    
new_folders = ['figures', 'gifs', 'models']
for new_folder in new_folders:
    if not os.path.isdir(new_folder): 
        os.makedirs(new_folder)
# Out:
# Wall time: 964 ms

# %% [markdown]
# ## 1.2 Load data
# #### 1.2.1 The input images loaded have amplitudes of 0 to 1 per pixel, and the speckle images have amplitude 0 to 255

# %%
out_dim = 28
speckle_dim = 112 #56
image_dim = speckle_dim
Use_root    = False
phase_shift = False


file_location = 'Data_1m.h5'
hf = h5py.File( my_path + file_location , 'r')


# Original/input image filenames, just renaming the handles for ease I guess
orig_img_filenames =  {'digi': 'Training/Original_images/MNIST',
                      'fash': 'Training/Original_images/Fashion-MNIST',
                      'rand': 'Training/Original_images/Random Patterns',
                      'fash_test': 'Testing/Original_images/MNIST',
                      'digi_test': 'Testing/Original_images/Fashion-MNIST',
                      'punc': 'Testing/Original_images/Muybridge Punch'}

#They are creating empty datasets named digi, fash, etc..
#The output is orig_imgs dictionary having "digi": then the dataset, "fash": then the dataset and so on
orig_imgs = {dataset: None for dataset in orig_img_filenames}

#They are filling these datasets in the "orig_imgs" dictionary as np arrays
for dataset, filename in orig_img_filenames.items():
    # Load
    fl = hf[filename]
    orig_imgs[dataset] =  np.array(fl)


## TRAIN
#Put all the datasets into one big dataset, y_train has 44000 training examples
#Dimensions of y_train is 44000 x (28x28) x 1; the x 1 is a trivial dimension, should be removed by np.squeeze
y_train = np.concatenate((orig_imgs['digi'],
                          orig_imgs['fash'],
                          orig_imgs['rand'],
                         ))

#Flatten the images, now y_train dimensions are 44000 x 784
y_train = np.squeeze(y_train.reshape(-1, 28*28, 1)) #-1 means infer that dimension. The x 1 dimension is removed by squeezing

## TEST
y_test = np.concatenate((orig_imgs['digi_test'],
                         orig_imgs['fash_test'],))

#y_test now has the dimensions of 6000x784
y_test = np.squeeze(y_test.reshape(-1, 28*28, 1))


## Example of each dataset
rows, cols = 1, len(orig_img_filenames)-2 # exclude test sets
f, ax_arr = plt.subplots(rows, cols, figsize=(20, 10))
ex = 1

i = 1
for name in (name for name in orig_img_filenames if 'test' not in name):
    plt.subplot(rows, cols, i)
    plt.imshow(orig_imgs[name][ex].reshape(28,28)) #reshaping examples as 2D arrays, to be able to draw them by plt.imshow
    axes_off()
    i+=1




# Load and resize all datasets

# Original/input image filenames
speckle_img_filenames =  {'digi': 'Training/Speckle_images/MNIST',
                      'fash': 'Training/Speckle_images/Fashion-MNIST',
                      'rand': 'Training/Speckle_images/Random Patterns',
                      'fash_test': 'Testing/Speckle_images/MNIST',
                      'digi_test': 'Testing/Speckle_images/Fashion-MNIST',
                      'punc': 'Testing/Speckle_images/Muybridge Punch'}

data_dict = {dataset: None for dataset in speckle_img_filenames}


# import speckle images and resize them from 224 to the chosen speckle_dim
for dataset, filename in speckle_img_filenames.items():
    print(f"Loading {dataset} ...")
    # Load
    fl = hf[filename]
    data_dict[dataset] =  np.array(fl)
    #To resize we recover the original image shape
    #data_dict[dataset].shape[0] is used instead of -1 in the reshape function, which means it is calculated, not inferred
    #cv2 resizer method needs the input as image (2D array) and not flattened
    Data_resize = np.reshape(data_dict[dataset], (data_dict[dataset].shape[0],224,224))
    
    #Temp array with the new dimensions, but it is flattened here
    Data_temp = np.zeros((data_dict[dataset].shape[0],speckle_dim*speckle_dim))
    # Resize
    for im in range(data_dict[dataset].shape[0]):
        #resize using cv2, then reshape as flattened and put in Data_temp
        Data_temp[im] = np.reshape(cv2.resize(Data_resize[im], dsize=(speckle_dim, speckle_dim), interpolation=cv2.INTER_AREA), (speckle_dim*speckle_dim))
    
    data_dict[dataset] = Data_temp            
    del Data_temp, Data_resize
    gc.collect()


#TRAIN
#x_train now has the dimensions of 44000x12544
x_train = np.concatenate((data_dict['digi'],
                          data_dict['fash'],
                          data_dict['rand'],
                         ))
# TEST
#x_test now has the dimensions of 6000x12544
x_test = np.concatenate((data_dict['digi_test'], data_dict['fash_test'],))

#x_test_ch now has the dimensions of 6000x12544x2
x_train_ch = real_to_channels_np(x_train.astype('float32'))
x_test_ch  = real_to_channels_np(x_test.astype('float32'))

hf.close()
# Out:
# Loading digi ...
# Loading fash ...
# Loading rand ...
# Loading fash_test ...
# Loading digi_test ...
# Loading punc ...

# %% [markdown]
# ### 1.2.2 Apply the nonlinear transformation that the SLM induces on amplitude and phase.
# ### After this cell, input images have amplitudes 0 to 255 per pixel

# %%
from scipy import interpolate

experimentalAmp   = np.load(my_path + 'amplitude.npy')

#The phases here are the actual phases in radian divided by pi
experimentalPhase = np.load(my_path + 'phase.npy')
experimentalPhase = np.append(experimentalPhase, experimentalPhase[-2] ) # add in missing datapoint

#x1 and x2 are arrays from 0 to 1, they have length of 101 (as pixel values range from 0 to 100, or 0 to 1 if normalized)
x1 = np.arange(0.0,101.0)/100.0
x2 = np.arange(0.0,101.0)/100.0
print(len(experimentalPhase), len(x2))
#testx = np.arange(0.0,100.0,0.5)/100.0

#Create interpolate objects, supply x and y, then supply the new x later
fSLMamp = interpolate.interp1d(x1, experimentalAmp/np.max(experimentalAmp))
fSLMphase = interpolate.interp1d(x2, experimentalPhase)


print(np.min(y_train), np.max(y_train))

#I don't understand why they scale the phases, maybe to make all of the features have the same numerical range
y_train_phase = fSLMphase(y_train)*255.0
y_test_phase  = fSLMphase(y_test)*255.0

#scale the pixel amplitudes to be 0 to 255, now they are just like the speckle amplitudes
y_train       = fSLMamp(y_train)*255.0
y_test        = fSLMamp(y_test)*255.0
print(np.min(y_train), np.max(y_train))
# Out:
# 101 101
# 0.0 1.0
# 3.113248752079867 255.0

# %% [markdown]
# ## 1.3 PyTorch Models

# %% [markdown]
# ### 1.3.1 Imports and check CUDA

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Check if CUDA is available and get the CUDA device name
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Using cuda device
# NVIDIA GeForce RTX 3080 Ti

# %% [markdown]
# ### 1.3.2 Define custom layers

# %%
class MyAmplitude(nn.Module):
    """ Custom Amplitude layer """
    def __init__(self):
        super().__init__()

    def forward(self,x):
        complex_x = (channels_to_complex(x) if x.shape[-1] == 2 else x)
        output = torch.abs(complex_x)
        return output
    
class MyReshape(nn.Module): 
    """ Custom Reshape layer """
    def __init__(self, d1, d2): 
        super(MyReshape, self).__init__() 
        self.d1 = d1
        self.d2 = d2
        
    def forward(self, x): 
        if len(x.shape) == 2:
            return x.view(x.shape[0], self.d1, self.d2) 
        elif len(x.shape) == 3:
            return x.view(x.shape[0], self.d1, self.d2, 2)
    
    def extra_repr(self):
        return 'in_size={}, out_size={}x{}'.format(self.d1*self.d2, self.d1, self.d2)

class MyHadamard(nn.Module):
    """ Custom Hadamard layer """
    def __init__(self, size_in):
        super().__init__()
        self.size_in = size_in
        
        # define weights
        weights = torch.Tensor(size_in)
        self.weights = nn.Parameter(weights) 

        # initialize weights
        nn.init.ones_(self.weights) # weight init

    def forward(self, x):  
        x = x.float()
        if len(x.shape) == 3:
            return complex_to_channels(channels_to_complex(x) * torch.complex(self.weights, 0*self.weights))
        else:
            return x*self.weights
        
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_in) 
    
class MyLinear(nn.Module):
    """ Custom Linear Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out)
        bias = torch.Tensor(size_out)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = self.weights
        b = self.bias
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
        
        return w_times_x_add_b
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)    
        
class MyComplexDense(nn.Module):
    """ Custom Complex Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out, 2)
        bias = torch.Tensor(size_out, 2)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = channels_to_complex(self.weights)
        b = channels_to_complex(self.bias)
        x = channels_to_complex(x)
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
            
        return complex_to_channels(w_times_x_add_b)
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)

# %% [markdown]
# ### 1.3.3 Define SSIM loss module, adapted from pytorch-msssim package to return the loss directly

# %%
def _fspecial_gauss_1d(size, sigma):
    r"""Create 1-D gauss kernel
    Args:
        size (int): the size of gauss kernel
        sigma (float): sigma of normal distribution
    Returns:
        torch.Tensor: 1D kernel (1 x 1 x size)
    """
    coords = torch.arange(size, dtype=torch.float)
    coords -= size // 2

    g = torch.exp(-(coords ** 2) / (2 * sigma ** 2))
    g /= g.sum()

    return g.unsqueeze(0).unsqueeze(0)

class SSIM_loss(torch.nn.Module):
    def __init__(
        self,
        data_range=255,
        size_average=True,
        win_size=11,
        win_sigma=1.5,
        channel=3,
        spatial_dims=2,
        K=(0.01, 0.03),
        nonnegative_ssim=False,
        mul = 1,
    ):
        r""" class for ssim
        Args:
            data_range (float or int, optional): value range of input images. (usually 1.0 or 255)
            size_average (bool, optional): if size_average=True, ssim of all images will be averaged as a scalar
            win_size: (int, optional): the size of gauss kernel
            win_sigma: (float, optional): sigma of normal distribution
            channel (int, optional): input channels (default: 3)
            K (list or tuple, optional): scalar constants (K1, K2). Try a larger K2 constant (e.g. 0.4) if you get a negative or NaN results.
            nonnegative_ssim (bool, optional): force the ssim response to be nonnegative with relu.
        """

        super(SSIM_loss, self).__init__()
        self.win_size = win_size
        self.win = _fspecial_gauss_1d(win_size, win_sigma).repeat([channel, 1] + [1] * spatial_dims)
        self.size_average = size_average
        self.data_range = data_range
        self.K = K
        self.nonnegative_ssim = nonnegative_ssim
        self.mul = mul

    def forward(self, X, Y):
        return self.mul-self.mul*ssim(
            X.reshape(-1, 1, 28, 28),
            Y.reshape(-1, 1, 28, 28),
            data_range=self.data_range,
            size_average=self.size_average,
            win=self.win,
            K=self.K,
            nonnegative_ssim=self.nonnegative_ssim,
        )

# %% [markdown]
# ### 1.3.4 Define train, test, validation and test_display functions

# %%
def train(model, epochs, optimizer, scheduler, loss, reg, lamb, train_loader, patience, min_delta):
    # Early stopping
    the_last_loss = 1e10
    trigger_times = 0
    
    # Train loop
    model.train()
    indx_epoch = 1
    for epoch in range(epochs): 
        indx_batch = 1
        for data in train_loader:  
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            model.zero_grad()  
            output = model(x) 
            
            # Multi-resolution loss
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0) + loss(output[1], y1) + loss(output[2], y2)
            
            # Regularization
            if reg == 'L2':
                loss_value = loss_value + lamb * torch.sum(torch.square(model.fc.weights.data))
            elif reg == 'Unitary':
                if len(model.fc.weights.data.shape) == 2:
                    W = model.fc.weights.data
                    W_T = torch.transpose(W, 0, 1)
                    I = torch.eye(W.shape[1]).to(device)
                    loss_value = loss_value + lamb * torch.sum(torch.abs(W_T @ W - I))
                elif len(model.fc.weights.data.shape) == 3:
                    complex_W = channels_to_complex(model.fc.weights.data)
                    complex_W_conj_T = torch.transpose(torch.conj(complex_W), 0, 1)
                    I = torch.eye(complex_W.shape[1]).to(device)
                    loss_value = loss_value + lamb * torch.sum(torch.abs(complex_W_conj_T @ complex_W - I))
            
            # Backpropagate with Hadamard weights constrained
            loss_value.backward()  
            optimizer.step()  
            with torch.no_grad():
                model.hadamard.weights.copy_(model.hadamard.weights.data.clamp(min=0.01, max = 1))

            print('Batch: {}/{}, Running Loss = {}'.format(indx_batch, len(train_loader), loss_value), end="\r") 
            indx_batch = indx_batch + 1
        
        # Loss over training dataset for this epoch OR Latest training loss
        train_loss = valid(model = model, valid_loader = train_loader, loss = loss)
        print('Epoch: {}/{}, The current training loss = {}'.format(indx_epoch, epochs, train_loss))
        # print('Epoch: {}/{}, Latest training loss = {}'.format(indx_epoch, epochs, loss_value))
        indx_epoch = indx_epoch + 1
        
        # Reduce learning rate
        #scheduler.step(train_loss)
        
        # Early stopping, Loss over valiation dataset for this epoch
        the_current_loss = valid(model = model, valid_loader = test_loader, loss = loss)
        print('The current validation loss:', the_current_loss)

        if the_current_loss > the_last_loss-min_delta:
            trigger_times += 1
            print('trigger times:', trigger_times)

            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                return

        else:
            print('trigger times: 0')
            trigger_times = 0

        the_last_loss = the_current_loss
        
def test(model, test_loader, loss):
    # Settings
    model.eval()
    loss_total = 0

    # Test data
    with torch.no_grad():
        for data in test_loader:
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            
            output = model(x)
            # Multi-resolution loss, but look at the original only
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0)
            loss_total += loss_value.item()
            
    MSE = loss_total / len(test_loader)
    print(f"Test MSE = {MSE}\n")
    
    return MSE  
    
def valid(model, valid_loader, loss):
    # Settings
    model.eval()
    loss_total = 0

    # Validation data
    with torch.no_grad():
        for data in valid_loader:
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            
            output = model(x)
            # Multi-resolution loss, but look at the original only
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0)
            loss_total += loss_value.item()
    return loss_total / len(valid_loader) 

def test_display(model, x_test_all, y_test_all, out_dim=28, speckle_dim = 112, vmax=255.0):
    model.eval()
    x = torch.tensor(x_test_all).to(device)
    y = torch.tensor(y_test_all)
    
    output = model(x)
    if isinstance(output, tuple) == False:
        output = output.cpu()
    if isinstance(output, tuple) == True:
        output = output[0].cpu()
    
    rows = 4
    f, ax_arr = plt.subplots(rows, 3, figsize=(20, 20))

    palette = copy(plt.cm.gray)
    palette.set_over('r', 1.0)
    palette.set_under('g', 1.0)
    palette.set_bad('b', 1.0)
    
    idxs = [0,1,3004,4001]
    for row in range(1,rows+1):
        # Original
        plt.subplot(rows,3, 3*row-2)
        this_image = y[idxs[row-1]].reshape(out_dim,out_dim)        
        plt.imshow(this_image,
                  norm=colors.Normalize(vmin=0.0, vmax=vmax, clip=False))
        if row == 1: plt.title('Original images', fontsize=30, y=1.12)
        axes_off()

        # Speckle
        plt.subplot(rows,3,3*row-2 + 1)
        this_image = x_test_ch[idxs[row-1],:,0].reshape(speckle_dim, speckle_dim)        
        plt.imshow(this_image)
        if row == 1: plt.title('Speckle images', fontsize=30, y=1.12)
        axes_off()

        # Reconstructed
        plt.subplot(rows,3,3*row-2 + 2)
        this_image = output[idxs[row-1]].detach().numpy().reshape(out_dim,out_dim)
        plt.imshow(this_image,
                  norm=colors.Normalize(vmin=0.0, vmax=vmax, clip=False))
        if row == 1: plt.title('Reconstructed images', fontsize=30, y=1.12)
        axes_off()

# %% [markdown]
# ### 1.3.5 Load datasets into Pytorch loaders

# %%
# Pyramidize the target images for mutli-resolution training
base_img_size = 28
def pyramidize(imgs, levels):
    
    # get images into right shape
    imgs = np.reshape(imgs, (imgs.shape[0], base_img_size, base_img_size))
    
    # do resizing
    resized_imgs = [np.array([cv2.resize(img, dsize=(int(base_img_size//2**i), 
                    int(base_img_size//2**i))) for img in imgs]) for i in range(levels)]
    
    return [np.reshape(size, (imgs.shape[0], int(imgs.shape[1]//2**i)**2))
            for i, size in enumerate(resized_imgs)]
    
y_train_p = pyramidize(y_train, levels=3)
y_test_p  = pyramidize(y_test, levels=3)


# Load datasets into a loader
batch_size = 64
class SpeckleDataset(Dataset):
    def __init__(self, X, Y0, Y1, Y2):
        self.X = torch.tensor(X).float()
        self.Y0 = torch.tensor(Y0).float()
        self.Y1 = torch.tensor(Y1).float()
        self.Y2 = torch.tensor(Y2).float()
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return (self.X[idx], self.Y0[idx], self.Y1[idx], self.Y2[idx])

train_set = SpeckleDataset(x_train_ch, y_train_p[0], y_train_p[1], y_train_p[2])
test_set = SpeckleDataset(x_test_ch, y_test_p[0], y_test_p[1], y_test_p[2])

train_loader = DataLoader(dataset = train_set, batch_size = batch_size, shuffle = True)
test_loader = DataLoader(dataset = test_set, batch_size = batch_size, shuffle = True)

# Clear what you don't need to free memory
del y_train, y_train_p, x_train, x_train_ch, y_test_p

# %% [markdown]
# ### 1.3.6 Building different models

# %% [markdown]
# ### 1.3.6.1 Model_1: Real layer with no regularization

# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.amplitude = MyAmplitude()
        self.fc = MyLinear(12544, 784)
        self.hadamard = MyHadamard(784)

    def forward(self, x):
        x = self.amplitude(x)
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Real_no_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'None', lamb = 0, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}'.format(epochs))

#Test the model
#net = torch.load('models/' +model_name + '_epoch_{}'.format(epochs)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (amplitude): MyAmplitude()
#   (fc): MyLinear(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
# Epoch: 289/300, The current training loss = 1692.8621008229811
# The current validation loss: 1064.5887197940908
# trigger times: 0
# Epoch: 290/300, The current training loss = 1692.061370317326
# The current validation loss: 1066.336151772357
# trigger times: 1
# Epoch: 291/300, The current training loss = 1690.4322147812954
# The current validation loss: 1064.2564424555353
# trigger times: 0
# Epoch: 292/300, The current training loss = 1688.1388666907021
# The current validation loss: 1065.604589584026
# trigger times: 1
# Epoch: 293/300, The current training loss = 1687.4341852942177
# The current validation loss: 1064.7393409242022
# trigger times: 0
# Epoch: 294/300, The current training loss = 1686.1417218585348
# The current validation loss: 1065.596871234001
# trigger times: 1
# Epoch: 295/300, The current training loss = 1684.9432985172716
# The current validation loss: 1064.270391585979
# trigger times: 0
# Epoch: 296/300, The current training loss = 1683.6484211766442
# The current validation loss: 1064.448606450507
# trigger times: 1
# Epoch: 297/300, The current training loss = 1682.332899049271
# The current validation loss: 1064.3250466204704
# trigger times: 0
# Epoch: 298/300, The current training loss = 1680.6435092659883
# The current validation loss: 1064.2692598383478
# trigger times: 0
# Epoch: 299/300, The current training loss = 1679.6968853972678
# The current validation loss: 1065.499514965301
# trigger times: 1
# Epoch: 300/300, The current training loss = 1678.23350471674
# The current validation loss: 1063.4700895268866
# trigger times: 0
# Test MSE = 1063.8380133446226

# %% [markdown]
# ### 1.3.6.2 Model_2: Real layer with L2 regularization

# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.amplitude = MyAmplitude()
        self.fc = MyLinear(12544, 784)
        self.hadamard = MyHadamard(784)

    def forward(self, x):
        x = self.amplitude(x)
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Real_L2_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
lamb = 0.03
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'L2', lamb = lamb, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb))

#Test the model
#net = torch.load('models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (amplitude): MyAmplitude()
#   (fc): MyLinear(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
# )
# Epoch: 1/300, The current training loss = 5203.995508948038
# The current validation loss: 3245.9224178233044
# trigger times: 0
# Epoch: 2/300, The current training loss = 4812.507002009902
# The current validation loss: 2759.222632874834
# trigger times: 0
# Epoch: 3/300, The current training loss = 4574.342577912087
# The current validation loss: 2476.9956444273603
# trigger times: 0
# Epoch: 4/300, The current training loss = 4400.290312656137
# The current validation loss: 2287.6942476313166
# trigger times: 0
# Epoch: 5/300, The current training loss = 4260.85473916697
# The current validation loss: 2145.915520850648
# trigger times: 0
# Epoch: 6/300, The current training loss = 4146.087231303371
# The current validation loss: 2036.8581049493018
# trigger times: 0
# Epoch: 7/300, The current training loss = 4047.1925836607465
# The current validation loss: 1951.7205511864195
# trigger times: 0
# Epoch: 8/300, The current training loss = 3959.0174461187316
# The current validation loss: 1874.7050495553524
# trigger times: 0
# Epoch: 9/300, The current training loss = 3879.1704743851064
# The current validation loss: 1811.0865842129322
# trigger times: 0
# Epoch: 10/300, The current training loss = 3809.723190307617
# The current validation loss: 1763.602922155502
# trigger times: 0
# Epoch: 11/300, The current training loss = 3745.512922420058
# The current validation loss: 1714.075173235954
# trigger times: 0
# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x = self.amplitude(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Complex_no_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'None', lamb = 0, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}'.format(epochs))

#Test the model
#net = torch.load('models/' + model_name + '_epoch_{}'.format(epochs)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 5220.627997110057
# The current validation loss: 3291.6487855302526
# trigger times: 0
# Epoch: 2/300, The current training loss = 4829.727209756541
# The current validation loss: 2801.363979907746
# trigger times: 0
# Epoch: 3/300, The current training loss = 4592.760206000749
# The current validation loss: 2517.000044153092
# trigger times: 0
# Epoch: 4/300, The current training loss = 4417.632070142169
# The current validation loss: 2327.8564842711103
# trigger times: 0
# Epoch: 5/300, The current training loss = 4278.272587266079
# The current validation loss: 2180.844809674202
# trigger times: 0
# Epoch: 6/300, The current training loss = 4159.768017081327
# The current validation loss: 2069.208676601978
# trigger times: 0
# Epoch: 7/300, The current training loss = 4063.1258037478424
# The current validation loss: 1980.4150754238697
# trigger times: 0
# Epoch: 8/300, The current training loss = 3974.0744135657023
# The current validation loss: 1904.378797165891
# trigger times: 0
# Epoch: 9/300, The current training loss = 3894.868212322856
# The current validation loss: 1838.5042945374835
# trigger times: 0
# Epoch: 10/300, The current training loss = 3824.240534227948
# The current validation loss: 1785.8772712869848
# trigger times: 0
# Epoch: 11/300, The current training loss = 3757.4088940287747
# The current validation loss: 1739.1786836664728
# trigger times: 0
# Epoch: 12/300, The current training loss = 3697.6709051797557
# The current validation loss: 1696.1999368870513
# trigger times: 0
# Epoch: 13/300, The current training loss = 3642.794186259425
# The current validation loss: 1658.8097495221077
# trigger times: 0
# Epoch: 14/300, The current training loss = 3590.7120659406796
# The current validation loss: 1627.944313860954
# trigger times: 0
# Epoch: 15/300, The current training loss = 3543.9999368357103
# The current validation loss: 1600.9033397918051
# trigger times: 0
# Epoch: 16/300, The current training loss = 3496.738909699196
# The current validation loss: 1571.7609772377825
# trigger times: 0
# Epoch: 17/300, The current training loss = 3449.531343327012
# The current validation loss: 1543.1926724048371
# trigger times: 0
# Epoch: 18/300, The current training loss = 3411.90780994504
# The current validation loss: 1523.7627342711103
# trigger times: 0
# Epoch: 19/300, The current training loss = 3372.778845143873
# The current validation loss: 1502.3958207800033
# trigger times: 0
# Epoch: 20/300, The current training loss = 3332.2507455515306
# The current validation loss: 1482.49230047997
# trigger times: 0
# Epoch: 21/300, The current training loss = 3298.3524290572764
# The current validation loss: 1463.7502610226895
# trigger times: 0
# Epoch: 22/300, The current training loss = 3267.669303716615
# Epoch: 280/300, The current training loss = 1654.4348288247752
# The current validation loss: 1019.6684810557264
# trigger times: 0
# Epoch: 281/300, The current training loss = 1653.320922496707
# The current validation loss: 1019.6902102206616
# trigger times: 1
# Epoch: 282/300, The current training loss = 1651.5729654001634
# The current validation loss: 1019.6512035613364
# trigger times: 0
# Epoch: 283/300, The current training loss = 1649.5451878392419
# The current validation loss: 1020.0814215477477
# trigger times: 1
# Epoch: 284/300, The current training loss = 1648.2265328695607
# The current validation loss: 1018.5696469570728
# trigger times: 0
# Epoch: 285/300, The current training loss = 1646.684799194336
# The current validation loss: 1019.2526537306766
# trigger times: 1
# Epoch: 286/300, The current training loss = 1645.2903399800146
# The current validation loss: 1019.973666576629
# trigger times: 2
# Epoch: 287/300, The current training loss = 1642.882881874262
# The current validation loss: 1018.2133444928108
# trigger times: 0
# Epoch: 288/300, The current training loss = 1641.8925745764443
# The current validation loss: 1017.1586485517786
# trigger times: 0
# Epoch: 289/300, The current training loss = 1640.190166207247
# The current validation loss: 1017.4241079776845
# trigger times: 1
# Epoch: 290/300, The current training loss = 1638.5533431297124
# The current validation loss: 1016.9601933905419
# trigger times: 0
# Epoch: 291/300, The current training loss = 1637.3373987951943
# The current validation loss: 1018.0247244327626
# trigger times: 1
# Epoch: 292/300, The current training loss = 1635.7079169694769
# The current validation loss: 1018.0984815232297
# trigger times: 2
# Epoch: 293/300, The current training loss = 1634.9556512167287
# The current validation loss: 1019.7158170659492
# trigger times: 3
# Epoch: 294/300, The current training loss = 1631.5529614825582
# The current validation loss: 1015.9322698065575
# trigger times: 0
# Epoch: 295/300, The current training loss = 1631.0908667985784
# The current validation loss: 1013.865005168509
# trigger times: 0
# Epoch: 296/300, The current training loss = 1628.7765942950582
# The current validation loss: 1016.4191193276263
# trigger times: 1
# Epoch: 297/300, The current training loss = 1627.4629644349563
# The current validation loss: 1015.9894707862367
# trigger times: 0
# Epoch: 298/300, The current training loss = 1626.2385830546534
# The current validation loss: 1015.132083973986
# trigger times: 0
# Epoch: 299/300, The current training loss = 1624.0705795288086
# The current validation loss: 1015.152591786486
# trigger times: 1
# Epoch: 300/300, The current training loss = 1623.1994227919467
# The current validation loss: 1015.2131607380319
# trigger times: 2
# Test MSE = 1015.378451732879

# %% [markdown]
# ### 1.3.6.4 Model_4: Complex layer with L2 regularization

# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x = self.amplitude(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Complex_L2_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
lamb = 0.03
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'L2', lamb = lamb, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb))

#Test the model
#net = torch.load('models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss =
# Epoch: 290/300, The current training loss = 1638.2572630061659
# The current validation loss: 1019.677227263755
# trigger times: 0
# Epoch: 291/300, The current training loss = 1637.0134855758313
# The current validation loss: 1019.9546002327128
# trigger times: 1
# Epoch: 292/300, The current training loss = 1635.913280043491
# The current validation loss: 1019.9339339885306
# trigger times: 0
# Epoch: 293/300, The current training loss = 1635.1602036232173
# The current validation loss: 1019.4540963680187
# trigger times: 0
# Epoch: 294/300, The current training loss = 1632.707295617392
# The current validation loss: 1020.3454726198886
# trigger times: 1
# Epoch: 295/300, The current training loss = 1631.4033325550167
# The current validation loss: 1018.6346948501912
# trigger times: 0
# Epoch: 296/300, The current training loss = 1629.7605196930642
# The current validation loss: 1018.9573662940492
# trigger times: 1
# Epoch: 297/300, The current training loss = 1627.656886610874
# The current validation loss: 1018.0028576140708
# trigger times: 0
# Epoch: 298/300, The current training loss = 1625.7352463478267
# The current validation loss: 1017.6543325870595
# trigger times: 0
# Epoch: 299/300, The current training loss = 1625.1201649155728
# The current validation loss: 1017.4520912982048
# trigger times: 0
# Epoch: 300/300, The current training loss = 1624.4817398426144
# The current validation loss: 1019.0169456968916
# trigger times: 1
# Test MSE = 1018.8149433541805

# %% [markdown]
# ### 1.3.6.5 Model_5: Complex layer with L2 regularization but with SSIM loss instead of MSE loss

# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x = self.amplitude(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Complex_L2_reg_SSIM'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss_train = SSIM_loss(mul = 20e3, channel=1, win_sigma = 5)
loss_test = nn.MSELoss()

#Train and save the model
epochs = 300
lamb = 0.03
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss_train, reg = 'L2', lamb = lamb, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb))

#Test the model
#net = torch.load('models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss_test)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 12805.074589219204
# The current validation loss: 9298.864288979388
# trigger times: 0
# Epoch: 2/300, The current training loss = 10901.691650390625
# The current validation loss: 7570.618787400266
# trigger times: 0
# Epoch: 3/300, The current training loss = 9722.014695278434
# The current validation loss: 6694.04796584109
# trigger times: 0
# Epoch: 4/300, The current training loss = 8974.363995219386
# The current validation loss: 6264.76404587766
# trigger times: 0
# Epoch: 5/300, The current training loss = 8392.770064952761
# The current validation loss: 5917.572099401596
# trigger times: 0
# Epoch: 6/300, The current training loss = 7879.319100313409
# The current validation loss: 5599.428731715426
# trigger times: 0
# Epoch: 7/300, The current training loss = 7513.931001884993
# The current validation loss: 5428.385160405585
# trigger times: 0
# Epoch: 8/300, The current training loss = 7160.11732092569
# The current validation loss: 5262.904681266622
# trigger times: 0
# Epoch: 9/300, The current training loss = 6895.524384254633
# The current validation loss: 5141.443307430186
# trigger times: 0
# Epoch: 10/300, The current training loss = 6694.655915016352
# The current validation loss: 5042.626890791224
# trigger times: 0
# Epoch: 11/300, The current training loss = 6493.056914573492
# The current validation loss: 4943.949883643617
# trigger times: 0
# Epoch: 12/300, The current training loss = 6316.784176848655
# The current validation loss: 4884.090643700133
# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x = self.amplitude(x)
        return x
    
net = Net(); net.to(device); print(net)
model_name = 'Complex_Unitary_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
lamb = 0.03
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'Unitary', lamb = lamb, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb))

#Test the model
#net = torch.load('models/' + model_name + '_epoch_{}_lamb_{}'.format(epochs, lamb)); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 5216.654902968296
# The current validation loss: 3287.0824078499004
# trigger times: 0
# Epoch: 2/300, The current training loss = 4827.435184922329
# The current validation loss: 2797.183921002327
# trigger times: 0
# Epoch: 3/300, The current training loss = 4590.019267947175
# The current validation loss: 2516.41766747008
# trigger times: 0
# Epoch: 4/300, The current training loss = 4412.237697512604
# The current validation loss: 2322.6930243309507
# trigger times: 0
# Epoch: 5/300, The current training loss = 4276.13108719227
# The current validation loss: 2180.9650229596077
# trigger times: 0
# Epoch: 6/300, The current training loss = 4159.153439898823
# The current validation loss: 2069.922420420545
# trigger times: 0
# Epoch: 7/300, The current training loss = 4060.636199951172
# The current validation loss: 1980.1036558759974
# trigger times: 0
# Epoch: 8/300, The current training loss = 3971.5176182236783
# The current validation loss: 1905.648606320645
# trigger times: 0
# Epoch: 9/300, The current training loss = 3892.773796613826
# The current validation loss: 1840.1094749937665
# trigger times: 0
# Epoch: 10/300, The current training loss = 3824.359842344772
# The current validation loss: 1790.1450935526098
# trigger times: 0
# Epoch: 11/300, The current training loss = 3757.7513104815816
# The current validation loss: 1740.7499272772607
# trigger times: 0
# Epoch: 12/300, The current training loss = 3697.883485306141
# The current validation loss: 1696.3853655875998
# trigger times: 0
# Epoch: 13/300, The current training loss = 3641.6327521745548
# The current validation loss: 1660.073208423371
# trigger times: 0
# Epoch: 14/300, The current training loss = 3587.3017801684005
# The current validation loss: 1625.8702886053857
# trigger times: 0
# Epoch: 15/300, The current training loss = 3540.1158181123956
# The current validation loss: 1595.7296181536735
# trigger times: 0
# Epoch: 16/300, The current training loss = 3495.1982900930007
# The current validation loss: 1570.1230598612035
# trigger times: 0
# Epoch: 17/300, The current training loss = 3451.784885850064
# The current validation loss: 1546.162353515625
# trigger times: 0
# Epoch: 18/300, The current training loss = 3410.872317646825
# The current validation loss: 1521.9959314224568
# trigger times: 0
# Epoch: 19/300, The current training loss = 3370.7959938936456
# The current validation loss: 1504.23595282372
# trigger times: 0
# Epoch: 20/300, The current training loss = 3333.8080987264943
# The current validation loss: 1483.8270861037233
# trigger times: 0
# Epoch: 21/300, The current training loss = 3297.5307429114055
# The current validation loss: 1464.9471175822805
# trigger times: 0
# Epoch: 22/300, The current training loss = 3264.710982566656
# The current validation loss: 1450.1567071143618
# trigger times: 0
# Epoch: 23/300, The current training loss = 3231.798113445903
# The current validation loss: 1437.1652858003656
# trigger times: 0
# Epoch: 24/300, The current training loss = 3200.185177115507
# The current validation loss: 1416.9995909345912
# trigger times: 0
# Epoch: 25/300, The current training loss = 3172.0810773982557
# trigger times: 1
# Epoch: 283/300, The current training loss = 1649.1383516178576
# The current validation loss: 1019.2489435723487
# trigger times: 0
# Epoch: 284/300, The current training loss = 1648.3970670478288
# The current validation loss: 1019.9261026585356
# trigger times: 1
# Epoch: 285/300, The current training loss = 1645.9928255302962
# The current validation loss: 1020.1028442382812
# trigger times: 2
# Epoch: 286/300, The current training loss = 1643.6246939370799
# The current validation loss: 1018.37650250374
# trigger times: 0
# Epoch: 287/300, The current training loss = 1642.2946170540743
# The current validation loss: 1021.1239403257979
# trigger times: 1
# Epoch: 288/300, The current training loss = 1641.127983802973
# The current validation loss: 1019.2967750062334
# trigger times: 0
# Epoch: 289/300, The current training loss = 1639.3507772046466
# The current validation loss: 1018.0174911174369
# trigger times: 0
# Epoch: 290/300, The current training loss = 1638.3018443972564
# The current validation loss: 1019.4491181069232
# trigger times: 1
# Epoch: 291/300, The current training loss = 1635.4345766999002
# The current validation loss: 1018.7085103785738
# trigger times: 0
# Epoch: 292/300, The current training loss = 1634.3728763669037
# The current validation loss: 1018.0813014253657
# trigger times: 0
# Epoch: 293/300, The current training loss = 1633.7816195820653
# The current validation loss: 1019.8716216391706
# trigger times: 1
# Epoch: 294/300, The current training loss = 1631.0797536095909
# The current validation loss: 1018.2304791389628
# trigger times: 0
# Epoch: 295/300, The current training loss = 1629.3418263280114
# The current validation loss: 1016.5632895611702
# trigger times: 0
# Epoch: 296/300, The current training loss = 1629.3906090314997
# The current validation loss: 1017.8472134204621
# trigger times: 1
# Epoch: 297/300, The current training loss = 1627.6820057713708
# The current validation loss: 1017.198261017495
# trigger times: 0
# Epoch: 298/300, The current training loss = 1625.551508881325
# The current validation loss: 1015.9389440658244
# trigger times: 0
# Epoch: 299/300, The current training loss = 1623.50585139075
# The current validation loss: 1016.175183884641
# trigger times: 1
# Epoch: 300/300, The current training loss = 1621.865058011787
# The current validation loss: 1017.4444989143534
# trigger times: 2
# Test MSE = 1017.228763661486

# %% [markdown]
# ### 1.3.6.7 Model_7: Complex layer with multi-resolution training and no regularization

# %%
# Define the model
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.reshape = MyReshape(28, 28)
        self.pool = nn.AvgPool2d(2)
        self.flatten = nn.Flatten(start_dim=1, end_dim=2)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        # First output
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x0 = self.amplitude(x)
        
        # Second output
        x = self.reshape(x)
        x_real_pool = self.pool(x[:,:,:,0])
        x_imag_pool = self.pool(x[:,:,:,1])
        x = torch.stack((x_real_pool, x_imag_pool), dim = 3)
        x1 = self.flatten(x)
        x1 = self.amplitude(x1)

        # Third output
        x_real_pool = self.pool(x[:,:,:,0])
        x_imag_pool = self.pool(x[:,:,:,1])
        x = torch.stack((x_real_pool, x_imag_pool), dim = 3)
        x2 = self.flatten(x)
        x2 = self.amplitude(x2)
        
        return (x0, x1, x2)
    
net = Net(); net.to(device); print(net)
model_name = 'Complex_MultiRes_no_reg'
learning_rate = 1e-5
optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
loss = nn.MSELoss()

#Train and save the model
epochs = 300
train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'Unitary', lamb = 0.03, train_loader = train_loader, patience = 8, min_delta = 1e-4)
torch.save(net, 'models/' + model_name + '_epoch_{}'.format(epochs))

#Test the model
#net = torch.load('models/' + 'model_name + '_epoch_{}'.format(epochs)'); net.to(device)
test(model = net, test_loader = test_loader, loss = loss)
test_display(model = net, x_test_all = x_test_ch, y_test_all = y_test)
# Out:
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (reshape): MyReshape(in_size=784, out_size=28x28)
#   (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (flatten): Flatten(start_dim=1, end_dim=2)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 4844.282873819041
# The current validation loss: 2736.177269468916
# trigger times: 0
# Epoch: 2/300, The current training loss = 4487.591633286587
# The current validation loss: 2296.7400525681514
# trigger times: 0
# Epoch: 3/300, The current training loss = 4288.826521052871
# The current validation loss: 2082.2776307450963
# trigger times: 0
# Epoch: 4/300, The current training loss = 4137.398895263672
# The current validation loss: 1928.4618153673537
# trigger times: 0
# Epoch: 5/300, The current training loss = 4010.529977842819
# The current validation loss: 1819.7505778860539
# trigger times: 0
# Epoch: 6/300, The current training loss = 3905.8763363860376
# The current validation loss: 1735.81148577751
# trigger times: 0
# Epoch: 7/300, The current training loss = 3824.057419532953
# The current validation loss: 1676.0330706657248
# trigger times: 0
# Epoch: 8/300, The current training loss = 3744.503282768782
# The current validation loss: 1617.05754186752
# trigger times: 0
# Epoch: 9/300, The current training loss = 3675.278658489848
# The current validation loss: 1573.354777883976
# trigger times: 0
# Epoch: 10/300, The current training loss = 3609.9797810399255
# The current validation loss: 1535.0869582155917
# trigger times: 0
# Epoch: 11/300, The current training loss = 3549.3106118135674
# The current validation loss: 1502.198343479887
# trigger times: 0
# Epoch: 12/300, The current training loss = 3496.3481246593387
# The current validation loss: 1474.073388931599
# trigger times: 0
# Epoch: 13/300, The current training loss = 3449.1410103731378
# The current validation loss: 1448.310441686752
# trigger times: 0
# Epoch: 14/300, The current training loss = 3398.336139057958
# The current validation loss: 1418.4072668197307
# trigger times: 0
# Epoch: 15/300, The current training loss = 3357.6623102232465
# The current validation loss: 1402.356955670296
# trigger times: 0
# Epoch: 16/300, The current training loss = 3313.7226647665334
# The current validation loss: 1385.1046584109042
# trigger times: 0
# Epoch: 17/300, The current training loss = 3276.11727621389
# The current validation loss: 1368.7078078249667
# trigger times: 0
# Epoch: 18/300, The current training loss = 3237.3030228725697
# The current validation loss: 1353.6295789353392
# trigger times: 0
# Epoch: 19/300, The current training loss = 3204.1644141618594
# The current validation loss: 1336.673850201546
# trigger times: 0
# Epoch: 20/300, The current training loss = 3172.520689853402
# The current validation loss: 1326.7816460792055
# trigger times: 0
# Epoch: 21/300, The current training loss = 3135.598787529524
# The current validation loss: 1311.6733684133976
# trigger times: 0
# Epoch: 22/300, The current training loss = 3108.6389649856924
# The current validation loss: 1300.0966407288897
# trigger times: 0
# Epoch: 23/300, The current training loss = 3076.9237961879994
# The current validation loss: 1285.1761968085107
# trigger times: 0
# Epoch: 24/300, The current training loss = 3052.3296973649844
# The current validation loss: 1281.55359795753
# The current validation loss: 1012.542792137633
# trigger times: 1
# Epoch: 283/300, The current training loss = 1659.3712816460188
# The current validation loss: 1009.3018909210855
# trigger times: 0
# Epoch: 284/300, The current training loss = 1654.7050823832667
# The current validation loss: 1012.5556095204455
# trigger times: 1
# Epoch: 285/300, The current training loss = 1655.5600837884947
# The current validation loss: 1009.3279224152261
# trigger times: 0
# Epoch: 286/300, The current training loss = 1654.2006768514943
# The current validation loss: 1009.4557261365525
# trigger times: 1
# Epoch: 287/300, The current training loss = 1650.4418870792833
# The current validation loss: 1005.848869161403
# trigger times: 0
# Epoch: 288/300, The current training loss = 1649.1179912478424
# The current validation loss: 1008.4758346232962
# trigger times: 1
# Epoch: 289/300, The current training loss = 1647.867600197016
# The current validation loss: 1007.3598230240193
# trigger times: 0
# Epoch: 290/300, The current training loss = 1647.8874637692475
# The current validation loss: 1008.5882685235206
# trigger times: 1
# Epoch: 291/300, The current training loss = 1646.3494693844818
# The current validation loss: 1007.8442791877909
# trigger times: 0
# Epoch: 292/300, The current training loss = 1645.937081802723
# The current validation loss: 1005.8705139160156
# trigger times: 0
# Epoch: 293/300, The current training loss = 1644.769717371741
# The current validation loss: 1008.500319460605
# trigger times: 1
# Epoch: 294/300, The current training loss = 1642.1407147784566
# The current validation loss: 1007.9707959763547
# trigger times: 0
# Epoch: 295/300, The current training loss = 1639.5911453601925
# The current validation loss: 1004.9567215290475
# trigger times: 0
# Epoch: 296/300, The current training loss = 1640.367257583973
# The current validation loss: 1007.0633616345993
# trigger times: 1
# Epoch: 297/300, The current training loss = 1635.6403334861577
# The current validation loss: 1006.1729125976562
# trigger times: 0
# Epoch: 298/300, The current training loss = 1638.1455267972724
# The current validation loss: 1008.2169332301363
# trigger times: 1
# Epoch: 299/300, The current training loss = 1634.8885870645213
# The current validation loss: 1004.401671064661
# trigger times: 0
# Epoch: 300/300, The current training loss = 1633.8564603938612
# The current validation loss: 1004.8315819273604
# trigger times: 1
# Test MSE = 1004.6147389513382

# %% [markdown]
# # PART 2 : Muybridge video punch example (1 meter)

# %% [markdown]
# ### 2.1 General setup

# %%
# %%time 
# Change to appropriate path
my_path = ''


import os
import gc

from matplotlib import pyplot as plt
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['axes.linewidth'] = 0

import numpy as np
import pickle
import h5py
import cv2
from IPython.display import display, clear_output
from copy import copy
from matplotlib import colors

from ComplexNetsTorch import *

import subprocess
import imageio
from IPython.display import HTML

def axes_off():
    cur_axes = plt.gca()
    cur_axes.axes.get_xaxis().set_visible(False)
    cur_axes.axes.get_yaxis().set_visible(False)
    
new_folders = ['figures', 'gifs', 'models']
for new_folder in new_folders:
    if not os.path.isdir(new_folder): 
        os.makedirs(new_folder)
# Out:
# Wall time: 0 ns

# %% [markdown]
# ### 2.2 Imports and check CUDA

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Check if CUDA is available and get the CUDA device name
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Using cuda device
# NVIDIA GeForce RTX 3080 Ti

# %% [markdown]
# ### 2.3 Define custom layers

# %%
class MyAmplitude(nn.Module):
    """ Custom Amplitude layer """
    def __init__(self):
        super().__init__()

    def forward(self,x):
        complex_x = (channels_to_complex(x) if x.shape[-1] == 2 else x)
        output = torch.abs(complex_x)
        return output
    
class MyReshape(nn.Module): 
    """ Custom Reshape layer """
    def __init__(self, d1, d2): 
        super(MyReshape, self).__init__() 
        self.d1 = d1
        self.d2 = d2
        
    def forward(self, x): 
        if len(x.shape) == 2:
            return x.view(x.shape[0], self.d1, self.d2) 
        elif len(x.shape) == 3:
            return x.view(x.shape[0], self.d1, self.d2, 2)
    
    def extra_repr(self):
        return 'in_size={}, out_size={}x{}'.format(self.d1*self.d2, self.d1, self.d2)

class MyHadamard(nn.Module):
    """ Custom Hadamard layer """
    def __init__(self, size_in):
        super().__init__()
        self.size_in = size_in
        
        # define weights
        weights = torch.Tensor(size_in)
        self.weights = nn.Parameter(weights) 

        # initialize weights
        nn.init.ones_(self.weights) # weight init

    def forward(self, x):  
        x = x.float()
        if len(x.shape) == 3:
            return complex_to_channels(channels_to_complex(x) * torch.complex(self.weights, 0*self.weights))
        else:
            return x*self.weights
        
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_in) 
    
class MyLinear(nn.Module):
    """ Custom Linear Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out)
        bias = torch.Tensor(size_out)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = self.weights
        b = self.bias
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
        
        return w_times_x_add_b
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)    
        
class MyComplexDense(nn.Module):
    """ Custom Complex Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out, 2)
        bias = torch.Tensor(size_out, 2)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = channels_to_complex(self.weights)
        b = channels_to_complex(self.bias)
        x = channels_to_complex(x)
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
            
        return complex_to_channels(w_times_x_add_b)
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)

# %% [markdown]
# ### 2.4 Load data
# ### The input images loaded have amplitudes of 0 to 1 per pixel, and the speckle images have amplitude 0 to 255

# %%
out_dim = 28
speckle_dim = 112 #56
image_dim = speckle_dim
Use_root    = False
phase_shift = False


file_location = 'Data_1m.h5'
hf = h5py.File( my_path + file_location , 'r')


# Original/input image filenames, just renaming the handles for ease I guess
orig_img_filenames =  {'punc': 'Testing/Original_images/Muybridge Punch'}

#They are creating empty datasets named digi, fash, etc..
#The output is orig_imgs dictionary having "digi": then the dataset, "fash": then the dataset and so on
orig_imgs = {dataset: None for dataset in orig_img_filenames}

#They are filling these datasets in the "orig_imgs" dictionary as np arrays
for dataset, filename in orig_img_filenames.items():
    # Load
    fl = hf[filename]
    orig_imgs[dataset] =  np.array(fl)

# Load and resize all datasets

# Original/input image filenames
speckle_img_filenames =  {'punc': 'Testing/Speckle_images/Muybridge Punch'}

data_dict = {dataset: None for dataset in speckle_img_filenames}


# import speckle images and resize them from 224 to the chosen speckle_dim
for dataset, filename in speckle_img_filenames.items():
    # Load
    fl = hf[filename]
    data_dict[dataset] =  np.array(fl)
    #To resize we recover the original image shape
    #data_dict[dataset].shape[0] is used instead of -1 in the reshape function, which means it is calculated, not inferred
    #cv2 resizer method needs the input as image (2D array) and not flattened
    Data_resize = np.reshape(data_dict[dataset], (data_dict[dataset].shape[0],224,224))
    
    #Temp array with the new dimensions, but it is flattened here
    Data_temp = np.zeros((data_dict[dataset].shape[0],speckle_dim*speckle_dim))
    # Resize
    for im in range(data_dict[dataset].shape[0]):
        #resize using cv2, then reshape as flattened and put in Data_temp
        Data_temp[im] = np.reshape(cv2.resize(Data_resize[im], dsize=(speckle_dim, speckle_dim), interpolation=cv2.INTER_AREA), (speckle_dim*speckle_dim))
    
    data_dict[dataset] = Data_temp            
    del Data_temp, Data_resize
    gc.collect()

hf.close()

# %% [markdown]
# ### 2.5 Load the model to use

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc = MyComplexDense(12544, 784)
        self.hadamard = MyHadamard(784)
        self.amplitude = MyAmplitude()

    def forward(self, x):
        x = self.fc(x)
        #x = F.relu(x)
        x = self.hadamard(x)
        x = self.amplitude(x)
        return x

model_name = 'Complex_L2_reg_epoch_300_lamb_0.03'
net = torch.load('models/' + model_name)

# %% [markdown]
# ### 2.6 Create GIF funtion

# %%
#Create GIF funtion
def create_and_save_gif(input_data, output_filename, resolution):
    # reshape
    input_data = input_data.reshape(-1, resolution, resolution)
    
    # normalise to 0,255 range
    input_data -= input_data.min()
    input_data *= 255/input_data.max()

    # create and save gif
    imageio.mimsave(output_filename, input_data.astype('uint8'))

# %% [markdown]
# ### 2.7 Reconstruct the original GIF, speckle GIF, and reconstructed GIF

# %%
# Video name and speckle resolution
spec_res = 112

#Reconstruct GIF and compare to original
vid = 'punc'

## ORIG GIF
orig_vid = orig_imgs[vid]
orig_fname = f'gifs/orig_{vid}.gif'
create_and_save_gif(orig_vid, orig_fname, 28)


## SPECKLE GIF 
spec_vid = data_dict[vid]
spec_fname = f'gifs/1m_{spec_res}x{spec_res}_{vid}_speckles.gif'
create_and_save_gif(spec_vid, spec_fname, spec_res)


## PREDICTED GIF
spec_vid = torch.tensor(real_to_channels_np(spec_vid)).to(device)
pred_vid = net(spec_vid)
pred_fname = f'gifs/{vid}_{model_name}.gif'
create_and_save_gif(pred_vid.cpu().detach().numpy(), pred_fname, 28)

## GENERATE TRIPTYCHS
subprocess.call("bash triptych.sh "
            f"{orig_fname} "
            f"{spec_fname} "
            f"{pred_fname} "
            f"{image_dim} "
            f"{spec_res} "
            f"{image_dim} "
            f"triptychs/triptych_{model_name}_{vid}.gif", shell=True)
# Out:
# 127

# %% [markdown]
# ### 2.8 Show examples of reconstructed images

# %%
indxs = [0, 5, 9]
f, ax_arr = plt.subplots(3, 3, figsize=(20, 20))

# Original
orig_vid = np.squeeze(orig_vid)
plt.subplot(3,3,1)        
plt.imshow(orig_vid[indxs[0]])
plt.title('Original images', fontsize=30, y=1.12)
axes_off()

plt.subplot(3,3,4)        
plt.imshow(orig_vid[indxs[1]])
axes_off()

plt.subplot(3,3,7)      
plt.imshow(orig_vid[indxs[2]])
axes_off()

# Speckle
plt.subplot(3,3,2)        
plt.imshow(spec_vid[indxs[0],:,0].cpu().reshape(112, 112))
plt.title('Speckle images', fontsize=30, y=1.12)
axes_off()

plt.subplot(3,3,5)        
plt.imshow(spec_vid[indxs[1],:,0].cpu().reshape(112, 112))
axes_off()

plt.subplot(3,3,8)      
plt.imshow(spec_vid[indxs[2],:,0].cpu().reshape(112, 112))
axes_off()

# Reconstructed
plt.subplot(3,3,3)        
plt.imshow(pred_vid[indxs[0]].cpu().detach().numpy().reshape(28,28))
plt.title('Reconstructed images', fontsize=30, y=1.12)
axes_off()

plt.subplot(3,3,6)        
plt.imshow(pred_vid[indxs[1]].cpu().detach().numpy().reshape(28,28))
axes_off()

plt.subplot(3,3,9)      
plt.imshow(pred_vid[indxs[2]].cpu().detach().numpy().reshape(28,28))
axes_off()

# %% [markdown]
# # PART 3 : Impact of speckle resolution

# %% [markdown]
# ### 3.1 General setup

# %%
# %%time 
# Change to appropriate path
my_path = ''


import os
import gc
import time

from matplotlib import pyplot as plt
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['axes.linewidth'] = 0

import numpy as np
import pickle
import h5py
import cv2
from IPython.display import display, clear_output
from copy import copy
from matplotlib import colors

from ComplexNetsTorch import *

import subprocess
import imageio
from IPython.display import HTML

def axes_off():
    cur_axes = plt.gca()
    cur_axes.axes.get_xaxis().set_visible(False)
    cur_axes.axes.get_yaxis().set_visible(False)
    
new_folders = ['figures', 'gifs', 'models']
for new_folder in new_folders:
    if not os.path.isdir(new_folder): 
        os.makedirs(new_folder)
# Out:
# Wall time: 0 ns

# %% [markdown]
# ### 3.2 Imports and check CUDA

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

#Check if CUDA is available and get the CUDA device name
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Using cuda device
# NVIDIA GeForce RTX 3080 Ti

# %% [markdown]
# ### 3.3 Define custom layers

# %%
class MyAmplitude(nn.Module):
    """ Custom Amplitude layer """
    def __init__(self):
        super().__init__()

    def forward(self,x):
        complex_x = (channels_to_complex(x) if x.shape[-1] == 2 else x)
        output = torch.abs(complex_x)
        return output
    
class MyReshape(nn.Module): 
    """ Custom Reshape layer """
    def __init__(self, d1, d2): 
        super(MyReshape, self).__init__() 
        self.d1 = d1
        self.d2 = d2
        
    def forward(self, x): 
        if len(x.shape) == 2:
            return x.view(x.shape[0], self.d1, self.d2) 
        elif len(x.shape) == 3:
            return x.view(x.shape[0], self.d1, self.d2, 2)
    
    def extra_repr(self):
        return 'in_size={}, out_size={}x{}'.format(self.d1*self.d2, self.d1, self.d2)

class MyHadamard(nn.Module):
    """ Custom Hadamard layer """
    def __init__(self, size_in):
        super().__init__()
        self.size_in = size_in
        
        # define weights
        weights = torch.Tensor(size_in)
        self.weights = nn.Parameter(weights) 

        # initialize weights
        nn.init.ones_(self.weights) # weight init

    def forward(self, x):  
        x = x.float()
        if len(x.shape) == 3:
            return complex_to_channels(channels_to_complex(x) * torch.complex(self.weights, 0*self.weights))
        else:
            return x*self.weights
        
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_in) 
    
class MyLinear(nn.Module):
    """ Custom Linear Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out)
        bias = torch.Tensor(size_out)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = self.weights
        b = self.bias
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
        
        return w_times_x_add_b
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)    
        
class MyComplexDense(nn.Module):
    """ Custom Complex Dense layer """
    def __init__(self, size_in, size_out, use_bias = False):
        super().__init__()
        self.size_in, self.size_out = size_in, size_out
        self.use_bias = use_bias
        
        # define weights and biases
        weights = torch.Tensor(size_in, size_out, 2)
        bias = torch.Tensor(size_out, 2)
        self.weights = nn.Parameter(weights) 
        self.bias = nn.Parameter(bias) 

        # weights init, golort uniform
        limit = math.sqrt(6 / (self.size_in + self.size_out))
        torch.nn.init.uniform_(self.weights, a = -limit, b = limit)
        
        # bias init
        torch.nn.init.zeros_(self.bias)

    def forward(self, x):
        x = x.float()
        w = channels_to_complex(self.weights)
        b = channels_to_complex(self.bias)
        x = channels_to_complex(x)
        
        if self.use_bias == True:
            w_times_x_add_b = x @ w + b
        else:
            w_times_x_add_b = x @ w
            
        return complex_to_channels(w_times_x_add_b)
    
    def extra_repr(self):
        return 'in_features={}, out_features={}'.format(self.size_in, self.size_out)

# %% [markdown]
# ### 3.4 Define train, test, validate, and test_display functions

# %%
def train(model, epochs, optimizer, scheduler, loss, reg, lamb, train_loader, patience, min_delta):
    # Early stopping
    the_last_loss = 1e10
    trigger_times = 0
    
    # Train loop
    model.train()
    indx_epoch = 1
    for epoch in range(epochs): 
        indx_batch = 1
        for data in train_loader:  
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            model.zero_grad()  
            output = model(x) 
            
            # Multi-resolution loss
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0) + loss(output[1], y1) + loss(output[2], y2)
            
            # Regularization
            if reg == 'L2':
                loss_value = loss_value + lamb * torch.sum(torch.square(model.fc.weights.data))
            elif reg == 'Unitary':
                if len(model.fc.weights.data.shape) == 2:
                    W = model.fc.weights.data
                    W_T = torch.transpose(W, 0, 1)
                    I = torch.eye(W.shape[1]).to(device)
                    loss_value = loss_value + lamb * torch.sum(torch.abs(W_T @ W - I))
                elif len(model.fc.weights.data.shape) == 3:
                    complex_W = channels_to_complex(model.fc.weights.data)
                    complex_W_conj_T = torch.transpose(torch.conj(complex_W), 0, 1)
                    I = torch.eye(complex_W.shape[1]).to(device)
                    loss_value = loss_value + lamb * torch.sum(torch.abs(complex_W_conj_T @ complex_W - I))
            
            # Backpropagate with Hadamard weights constrained
            loss_value.backward()  
            optimizer.step()  
            with torch.no_grad():
                model.hadamard.weights.copy_(model.hadamard.weights.data.clamp(min=0.01, max = 1))

            print('Batch: {}/{}, Running Loss = {}'.format(indx_batch, len(train_loader), loss_value), end="\r") 
            indx_batch = indx_batch + 1
        
        # Loss over training dataset for this epoch OR Latest training loss
        train_loss = valid(model = model, valid_loader = train_loader, loss = loss)
        print('Epoch: {}/{}, The current training loss = {}'.format(indx_epoch, epochs, train_loss))
        # print('Epoch: {}/{}, Latest training loss = {}'.format(indx_epoch, epochs, loss_value))
        indx_epoch = indx_epoch + 1
        
        # Reduce learning rate
        #scheduler.step(train_loss)
        
        # Early stopping, Loss over valiation dataset for this epoch
        the_current_loss = valid(model = model, valid_loader = test_loader, loss = loss)
        print('The current validation loss:', the_current_loss)

        if the_current_loss > the_last_loss-min_delta:
            trigger_times += 1
            print('trigger times:', trigger_times)

            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                return

        else:
            print('trigger times: 0')
            trigger_times = 0

        the_last_loss = the_current_loss
        
def test(model, test_loader, loss):
    # Settings
    model.eval()
    loss_total = 0

    # Test data
    with torch.no_grad():
        for data in test_loader:
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            
            output = model(x)
            # Multi-resolution loss, but look at the original only
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0)
            loss_total += loss_value.item()
            
    MSE = loss_total / len(test_loader)
    print(f"Test MSE = {MSE}\n")
    
    return MSE  
    
def valid(model, valid_loader, loss):
    # Settings
    model.eval()
    loss_total = 0

    # Validation data
    with torch.no_grad():
        for data in valid_loader:
            x, y0, y1, y2 = data
            x = x.to(device)
            y0 = y0.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
            
            output = model(x)
            # Multi-resolution loss, but look at the original only
            if isinstance(output, tuple) == False:
                loss_value = loss(output, y0)
            elif isinstance(output, tuple) == True:
                loss_value = loss(output[0], y0)
            loss_total += loss_value.item()
    return loss_total / len(valid_loader) 

def test_display(model, x_test_all, y_test_all, out_dim=28, speckle_dim = 112, vmax=255.0):
    model.eval()
    x = torch.tensor(x_test_all).to(device)
    y = torch.tensor(y_test_all)
    
    output = model(x)
    if isinstance(output, tuple) == False:
        output = output.cpu()
    if isinstance(output, tuple) == True:
        output = output[0].cpu()
    
    rows = 4
    f, ax_arr = plt.subplots(rows, 3, figsize=(20, 20))

    palette = copy(plt.cm.gray)
    palette.set_over('r', 1.0)
    palette.set_under('g', 1.0)
    palette.set_bad('b', 1.0)
    
    idxs = [0,1,3004,4001]
    for row in range(1,rows+1):
        # Original
        plt.subplot(rows,3, 3*row-2)
        this_image = y[idxs[row-1]].reshape(out_dim,out_dim)        
        plt.imshow(this_image,
                  norm=colors.Normalize(vmin=0.0, vmax=vmax, clip=False))
        if row == 1: plt.title('Original images', fontsize=30, y=1.12)
        axes_off()

        # Speckle
        plt.subplot(rows,3,3*row-2 + 1)
        this_image = x_test_ch[idxs[row-1],:,0].reshape(speckle_dim, speckle_dim)        
        plt.imshow(this_image)
        if row == 1: plt.title('Speckle images', fontsize=30, y=1.12)
        axes_off()

        # Reconstructed
        plt.subplot(rows,3,3*row-2 + 2)
        this_image = output[idxs[row-1]].detach().numpy().reshape(out_dim,out_dim)
        plt.imshow(this_image,
                  norm=colors.Normalize(vmin=0.0, vmax=vmax, clip=False))
        if row == 1: plt.title('Reconstructed images', fontsize=30, y=1.12)
        axes_off()

# %% [markdown]
# ### 3.5 Load input images
# ### The input images loaded have amplitudes of 0 to 1 per pixel

# %% [markdown]
# #### 3.5.1 Load input images

# %%
out_dim = 28
Use_root    = False
phase_shift = False


file_location = 'Data_1m.h5'
hf = h5py.File( my_path + file_location , 'r')


# Original/input image filenames, just renaming the handles for ease I guess
orig_img_filenames =  {'digi': 'Training/Original_images/MNIST',
                      'fash': 'Training/Original_images/Fashion-MNIST',
                      'rand': 'Training/Original_images/Random Patterns',
                      'fash_test': 'Testing/Original_images/MNIST',
                      'digi_test': 'Testing/Original_images/Fashion-MNIST',
                      'punc': 'Testing/Original_images/Muybridge Punch'}

#They are creating empty datasets named digi, fash, etc..
#The output is orig_imgs dictionary having "digi": then the dataset, "fash": then the dataset and so on
orig_imgs = {dataset: None for dataset in orig_img_filenames}

#They are filling these datasets in the "orig_imgs" dictionary as np arrays
for dataset, filename in orig_img_filenames.items():
    # Load
    fl = hf[filename]
    orig_imgs[dataset] =  np.array(fl)


## TRAIN
#Put all the datasets into one big dataset, y_train has 44000 training examples
#Dimensions of y_train is 44000 x (28x28) x 1; the x 1 is a trivial dimension, should be removed by np.squeeze
y_train = np.concatenate((orig_imgs['digi'],
                          orig_imgs['fash'],
                          orig_imgs['rand'],
                         ))

#Flatten the images, now y_train dimensions are 44000 x 784
y_train = np.squeeze(y_train.reshape(-1, 28*28, 1)) #-1 means infer that dimension. The x 1 dimension is removed by squeezing

## TEST
y_test = np.concatenate((orig_imgs['digi_test'],
                         orig_imgs['fash_test'],))

#y_test now has the dimensions of 6000x784
y_test = np.squeeze(y_test.reshape(-1, 28*28, 1))

hf.close()

# %% [markdown]
# #### 3.5.2 Apply the nonlinear transformation that the SLM induces on amplitude and phase.
# #### After this cell, input images have amplitudes 0 to 255 per pixel

# %%
from scipy import interpolate

experimentalAmp   = np.load(my_path + 'amplitude.npy')

#The phases here are the actual phases in radian divided by pi
experimentalPhase = np.load(my_path + 'phase.npy')
experimentalPhase = np.append(experimentalPhase, experimentalPhase[-2] ) # add in missing datapoint

#x1 and x2 are arrays from 0 to 1, they have length of 101 (as pixel values range from 0 to 100, or 0 to 1 if normalized)
x1 = np.arange(0.0,101.0)/100.0
x2 = np.arange(0.0,101.0)/100.0
print(len(experimentalPhase), len(x2))
#testx = np.arange(0.0,100.0,0.5)/100.0

#Create interpolate objects, supply x and y, then supply the new x later
fSLMamp = interpolate.interp1d(x1, experimentalAmp/np.max(experimentalAmp))
fSLMphase = interpolate.interp1d(x2, experimentalPhase)


print(np.min(y_train), np.max(y_train))

#I don't understand why they scale the phases, maybe to make all of the features have the same numerical range
y_train_phase = fSLMphase(y_train)*255.0
y_test_phase  = fSLMphase(y_test)*255.0

#scale the pixel amplitudes to be 0 to 255, now they are just like the speckle amplitudes
y_train       = fSLMamp(y_train)*255.0
y_test        = fSLMamp(y_test)*255.0
print(np.min(y_train), np.max(y_train))
# Out:
# 101 101
# 0.0 1.0
# 3.113248752079867 255.0

# %% [markdown]
# ### 3.6 Load speckles and scale to different resolutions then train, save and test the model
# ### The speckle images have amplitude 0 to 255

# %%
speckle_dim_list = [224, 112, 56, 28, 14]

i = 0
for speckle_dim in speckle_dim_list:
    i = i + 1
    
    print(f"=============================================")
    print(f"COMMENCING RESOLUTION {speckle_dim}x{speckle_dim}")
    print(f"---------------------------------------------")
    
    ##########################################
    # LOAD AND RESCALE
    ##########################################
    
    hf = h5py.File( my_path + file_location , 'r')
    
    speckle_img_filenames =  {'digi': 'Training/Speckle_images/MNIST',
                          'fash': 'Training/Speckle_images/Fashion-MNIST',
                          'rand': 'Training/Speckle_images/Random Patterns',
                          'fash_test': 'Testing/Speckle_images/MNIST',
                          'digi_test': 'Testing/Speckle_images/Fashion-MNIST'}

    data_dict = {dataset: None for dataset in speckle_img_filenames}

    # import speckle images and resize them from 224 to the chosen speckle_dim
    for dataset, filename in speckle_img_filenames.items():
        print(f"Loading {dataset} ...")
        # Load
        fl = hf[filename]
        data_dict[dataset] =  np.array(fl)
        #To resize we recover the original image shape
        #data_dict[dataset].shape[0] is used instead of -1 in the reshape function, which means it is calculated, not inferred
        #cv2 resizer method needs the input as image (2D array) and not flattened
        Data_resize = np.reshape(data_dict[dataset], (data_dict[dataset].shape[0],224,224))

        #Temp array with the new dimensions, but it is flattened here
        Data_temp = np.zeros((data_dict[dataset].shape[0],speckle_dim*speckle_dim))
        # Resize
        for im in range(data_dict[dataset].shape[0]):
            #resize using cv2, then reshape as flattened and put in Data_temp
            Data_temp[im] = np.reshape(cv2.resize(Data_resize[im], dsize=(speckle_dim, speckle_dim), interpolation=cv2.INTER_AREA), (speckle_dim*speckle_dim))

        data_dict[dataset] = Data_temp            
        del Data_temp, Data_resize
        gc.collect()


    #TRAIN
    #x_train now has the dimensions of 44000x12544
    x_train = np.concatenate((data_dict['digi'],
                              data_dict['fash'],
                              data_dict['rand'],
                             ))
    # TEST
    #x_test now has the dimensions of 6000x12544
    x_test = np.concatenate((data_dict['digi_test'], data_dict['fash_test'],))

    #x_test_ch now has the dimensions of 6000x12544x2
    x_train_ch = real_to_channels_np(x_train.astype('float32'))
    x_test_ch = real_to_channels_np(x_test.astype('float32'))
    
    hf.close()
    
    ##########################################
    # LOAD DATA INTO A PYTORCH LOADER
    ##########################################
    # Pyramidize the target images for mutli-resolution training
    base_img_size = 28
    def pyramidize(imgs, levels):

        # get images into right shape
        imgs = np.reshape(imgs, (imgs.shape[0], base_img_size, base_img_size))

        # do resizing
        resized_imgs = [np.array([cv2.resize(img, dsize=(int(base_img_size//2**i), 
                        int(base_img_size//2**i))) for img in imgs]) for i in range(levels)]

        return [np.reshape(size, (imgs.shape[0], int(imgs.shape[1]//2**i)**2))
                for i, size in enumerate(resized_imgs)]

    y_train_p = pyramidize(y_train, levels=3)
    y_test_p  = pyramidize(y_test, levels=3)


    # Load datasets into a loader
    batch_size = 64
    class SpeckleDataset(Dataset):
        def __init__(self, X, Y0, Y1, Y2):
            self.X = torch.tensor(X).float()
            self.Y0 = torch.tensor(Y0).float()
            self.Y1 = torch.tensor(Y1).float()
            self.Y2 = torch.tensor(Y2).float()

        def __len__(self):
            return len(self.X)

        def __getitem__(self, idx):
            return (self.X[idx], self.Y0[idx], self.Y1[idx], self.Y2[idx])

    train_set = SpeckleDataset(x_train_ch, y_train_p[0], y_train_p[1], y_train_p[2])
    test_set = SpeckleDataset(x_test_ch, y_test_p[0], y_test_p[1], y_test_p[2])

    train_loader = DataLoader(dataset = train_set, batch_size = batch_size, shuffle = True)
    test_loader = DataLoader(dataset = test_set, batch_size = batch_size, shuffle = True)

    # Clear what you don't need to free memory
    del y_train_p, y_test_p, x_train, x_train_ch, data_dict
    
    ##########################################
    # DEFINE, TRAIN, SAVE, AND TEST THE MODEL
    ##########################################
    # Define the model
    class Net(nn.Module):
        def __init__(self):
            super(Net, self).__init__()
            self.fc = MyComplexDense(speckle_dim*speckle_dim, 784)
            self.hadamard = MyHadamard(784)
            self.amplitude = MyAmplitude()

        def forward(self, x):
            x = self.fc(x)
            #x = F.relu(x)
            x = self.hadamard(x)
            x = self.amplitude(x)
            return x

    net = Net(); net.to(device); print(net)
    model_name = 'Complex_L2_reg'
    learning_rate = 1e-5
    optimizer = optim.SGD(net.parameters() ,lr = learning_rate)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer = optimizer, mode = 'min', factor = 0.1, patience = 2, min_lr = learning_rate/1e3, verbose = 1)
    loss = nn.MSELoss()

    #Train and save the model
    epochs = 300
    lamb = 0.03
    train(model = net, epochs = epochs, optimizer = optimizer, scheduler = scheduler, loss = loss, reg = 'L2', lamb = lamb, train_loader = train_loader, patience = 8, min_delta = 1e-4)
    torch.save(net, 'models/' + model_name + '_epoch_{}_lamb_{}_SpeckleRes_{}'.format(epochs, lamb, speckle_dim))

    #Test the model
    #net = torch.load('models/' + model_name + '_epoch_{}_lamb_{}_SpeckleRes_{}'.format(epochs, lamb, speckle_dim)); net.to(device)
    test(model = net, test_loader = test_loader, loss = loss)
    
    ##########################################
    # DRAW OUTPUT AT DIFFERENT SPECKLE RESOLUTIONS
    ##########################################
    net.eval()
    x = torch.tensor(x_test_ch).to(device)
    y = torch.tensor(y_test)
    
    output = net(x)
    if isinstance(output, tuple) == False:
        output = output.cpu()
    if isinstance(output, tuple) == True:
        output = output[0]
        output = output.cpu()
    
    cols = len(speckle_dim_list)
    if i == 1: f, ax_arr = plt.subplots(3, cols, figsize=(20, 20))

    palette = copy(plt.cm.gray)
    palette.set_over('r', 1.0)
    palette.set_under('g', 1.0)
    palette.set_bad('b', 1.0)
    
    image_indx = 1

    # Original
    plt.subplot(3, cols, i)
    this_image = y[image_indx].reshape(out_dim,out_dim)        
    plt.imshow(this_image,
              norm=colors.Normalize(vmin=0.0, vmax=255, clip=False))
    plt.xlabel('28 x 28', fontsize=30)
    if i == 1: plt.ylabel('Original images', fontsize=30)
    #axes_off()

    # Speckle
    plt.subplot(3, cols, i+cols)
    this_image = x_test_ch[image_indx,:,0].reshape(speckle_dim, speckle_dim)        
    plt.imshow(this_image)
    plt.xlabel('{} x {}'.format(speckle_dim, speckle_dim), fontsize=30)
    if i == 1: plt.ylabel('Speckle images', fontsize=30)
    #axes_off()

    # Reconstructed
    plt.subplot(3, cols, i+2*cols)
    this_image = output[image_indx].detach().numpy().reshape(out_dim,out_dim)
    plt.imshow(this_image,
              norm=colors.Normalize(vmin=0.0, vmax=255, clip=False))
    plt.xlabel('28 x 28', fontsize=30)
    if i == 1: plt.ylabel('Reconstructed images', fontsize=30)
    #axes_off()
    
    # Clear what you don't need to free memory
    del train_set, test_set, train_loader, test_loader
# Out:
# =============================================
# COMMENCING RESOLUTION 224x224
# ---------------------------------------------
# Loading digi ...
# Loading fash ...
# Loading rand ...
# Loading fash_test ...
# Loading digi_test ...
# Net(
#   (fc): MyComplexDense(in_features=50176, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 4539.9611014432685
# The current validation loss: 2386.727741647274
# trigger times: 0
# Epoch: 2/300, The current training loss = 4072.7722444756087
# The current validation loss: 1981.888326441988
# trigger times: 0
# Epoch: 3/300, The current training loss = 3761.973197049873
# The current validation loss: 1743.7787293779088
# trigger times: 0
# Epoch: 4/300, The current training loss = 3535.3818852624227
# The current validation loss: 1613.2484247735206
# trigger times: 0
# Epoch: 5/300, The current training loss = 3391.6944580078125
# The current validation loss: 1540.067507480053
# trigger times: 0
# Epoch: 6/300, The current training loss = 3231.5439233114553
# The current validation loss: 1457.6098321143618
# trigger times: 0
# Epoch: 7/300, The current training loss = 3098.4287677143893
# The current validation loss: 1405.0566315346575
# trigger times: 0
# Epoch: 8/300, The current training loss = 3013.513131784838
# The current validation loss: 1376.2334802505818
# trigger times: 0
# Epoch: 9/300, The current training loss = 2916.7279269196265
# The current validation loss: 1339.5066047830785
# trigger times: 0
# Epoch: 10/300, The current training loss = 2826.7554367420285
# The current validation loss: 1305.1321320229388
# trigger times: 0
# Epoch: 11/300, The current training loss = 2747.509775915811
# The current validation loss: 1274.5644284512134
# trigger times: 0
# Epoch: 12/300, The current training loss = 2666.4048814995344
# COMMENCING RESOLUTION 112x112
# ---------------------------------------------
# Loading digi ...
# Loading fash ...
# Loading rand ...
# Loading fash_test ...
# Loading digi_test ...
# Net(
#   (fc): MyComplexDense(in_features=12544, out_features=784)
#   (hadamard): MyHadamard(in_features=784, out_features=784)
#   (amplitude): MyAmplitude()
# )
# Epoch: 1/300, The current training loss = 5218.495081701944
# The current validation loss: 3290.0416285738033
# trigger times: 0
# Epoch: 2/300, The current training loss = 4827.24918809048
# The current validation loss: 2796.713389295213
# trigger times: 0
# Epoch: 3/300, The current training loss = 4588.457815480787
# The current validation loss: 2519.0677126620676
# trigger times: 0
# Epoch: 4/300, The current training loss = 4413.683765145235
# The current validation loss: 2323.357614070811
# trigger times: 0
# Epoch: 5/300, The current training loss = 4276.607017339662
# The current validation loss: 2182.608198449967
# trigger times: 0
# Epoch: 6/300, The current training loss = 4158.299774524778
# The current validation loss: 2066.811809133976
# trigger times: 0
# Epoch: 7/300, The current training loss = 4060.984852990439
# The current validation loss: 1978.835693359375
# trigger times: 0
# Epoch: 8/300, The current training loss = 3971.389367746752
# The current validation loss: 1901.2019848113364
# trigger times: 0
# Epoch: 9/300, The current training loss = 3896.1704701268395
# The current validation loss: 1842.3846591381316
# trigger times: 0
# Epoch: 10/300, The current training loss = 3823.782057296398
# The current validation loss: 1784.2270040309174
# trigger times: 0
# Epoch: 11/300, The current training loss = 3755.792351656182
# The current validation loss: 1738.994009464345
# trigger times: 0
# Epoch: 12/300, The current training loss = 3696.1136023942813
# The current validation loss: 1695.115978484458
# trigger times: 0
# Epoch: 13/300, The current training loss = 3642.302820604901
# The current validation loss: 1661.963259433178
# trigger times: 0
# Epoch: 14/300, The current training loss = 3593.2023340269575
# The current validation loss: 1629.6891271712932
# trigger times: 0
# Epoch: 15/300, The current training loss = 3539.0918674912564
# The current validation loss: 1593.8247966360539
# trigger times: 0
# Epoch: 16/300, The current training loss = 3494.7301419280298
# The current validation loss: 1568.7928830410572
# trigger times: 0
# Epoch: 17/300, The current training loss = 3450.40548599598
# The current validation loss: 1544.7273468666888
# trigger times: 0
# Epoch: 18/300, The current training loss = 3410.256359011628
# The current validation loss: 1521.3751934944314
# trigger times: 0
# Epoch: 19/300, The current training loss = 3372.2904098865597
# The current validation loss: 1503.7890079579454
# trigger times: 0
# Epoch: 20/300, The current training loss = 3335.1469109113827
# The current validation loss: 1483.960407662899
# trigger times: 0
# Epoch: 21/300, The current training loss = 3297.192060958507
# The current validation loss: 1462.4548248940325
# trigger times: 0
# Epoch: 22/300, The current training loss = 3263.119633519372
# The current validation loss: 1446.2413810567652
# trigger times: 0
# Epoch: 23/300, The current training loss = 3232.0966374596883
# The current validation loss: 1430.8082963659408
# trigger times: 0
# Epoch: 24/300, The current training loss = 3200.3564321828444
# The current validation loss: 1414.9335288189827
# trigger times: 0
# Epoch: 25/300, The current training loss = 3172.0988687914473
# The current validation loss: 1404.255787950881
# trigger times: 0
# Epoch: 26/300, The current training loss = 3142.2271629156066
# The current validation loss: 1391.7938868745844
# trigger times: 0
